# %% [markdown]
# <a href="https://colab.research.google.com/github/RISHOBGHOSH/Practice_python/blob/main/basic_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = {'A' : [1,2,3],
        'B' : [4,5,6] ,
        'C' : [7,8,9] }

df = pd.DataFrame(data)
print(df)
# Out:
#    A  B  C
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %%
print("Hello Romit Ghosh")
# Out:
# Hello Romit Ghosh

# %%
list = [1,2,3,4,5]
print(list)
# Out:
# [1, 2, 3, 4, 5]

# %%
def SUM_fun(a, b):
    c = a + b  # Correct assignment
    return c

print(SUM_fun(4, 5))
# Out:
# 9
